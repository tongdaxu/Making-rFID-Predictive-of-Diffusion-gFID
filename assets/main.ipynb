# %%
from ifid_data import data, datanew, evaluate_metric
import numpy as np

# psnr
print(evaluate_metric(datanew, "sit_b_w_o_cfg_gfid", "sit_b_w_o_cfg_is", k=10))
# print(evaluate_metric(data, "sit_b_w_cfg_gfid", "yymm", k=10))

print(evaluate_metric(datanew, "sit_xl_w_o_cfg_gfid", "sit_xl_w_o_cfg_is", k=10))
# print(evaluate_metric(data, "sit_xl_w_cfg_gfid", "yymm", k=10))
# Out:
# {'metric': 'ifid_linear_05', 'num_samples': 21, 'pearson': np.float64(0.6905286048124631), 'spearman': np.float64(0.7443975709266036), 'kendall_tau': np.float64(0.5489275776748804), 'top_10_overlap': 0.8, 'selection_regret': np.float64(2.0)}
# {'metric': 'ifid_linear_05', 'num_samples': 22, 'pearson': np.float64(0.7520714182031337), 'spearman': np.float64(0.7929963603427018), 'kendall_tau': np.float64(0.6073767001317861), 'top_10_overlap': 0.8, 'selection_regret': np.float64(1.38)}

# %%
from ifid_data import plot_metric
plot_metric("reconstruction_rfid", "rFID", "sit_b_w_o_cfg_gfid", "SiT/B w/o CFG gFID")
plot_metric("reconstruction_rfid", "rFID", "sit_xl_w_o_cfg_gfid", "SiT/XL w/o CFG gFID")
plot_metric("ifid_bn", "iFID", "sit_b_w_o_cfg_gfid", "SiT/B w/o CFG gFID")
plot_metric("ifid_bn", "iFID", "sit_xl_w_o_cfg_gfid", "SiT/XL w/o CFG gFID")
# Out:
# Linear regression: y = -5.534 x + 31.815
# Pearson correlation: -0.127
# Linear regression: y = -2.063 x + 15.495
# Pearson correlation: -0.081
# Linear regression: y = 0.744 x + 4.890
# Pearson correlation: 0.859
# Linear regression: y = 0.427 x + 1.175
# Pearson correlation: 0.883

# %%
# ifid
print(evaluate_metric(data, "sit_b_w_o_cfg_gfid", "ifid_bn", k=10))
print(evaluate_metric(data, "sit_b_w_cfg_gfid", "ifid_bn", k=10))

print(evaluate_metric(data, "sit_xl_w_o_cfg_gfid", "ifid_bn", k=10))
print(evaluate_metric(data, "sit_xl_w_cfg_gfid", "ifid_bn", k=10))

# %%
print(evaluate_metric(data, "sit_b_w_o_cfg_is", "iis", k=10))
print(evaluate_metric(data, "sit_b_w_cfg_is", "iis", k=10))

print(evaluate_metric(data, "sit_xl_w_o_cfg_is", "iis", k=10))
print(evaluate_metric(data, "sit_xl_w_cfg_is", "iis", k=10))

# %%
print(evaluate_metric(data, "sit_b_w_o_cfg_prec", "iprec", k=10))
print(evaluate_metric(data, "sit_b_w_cfg_prec", "iprec", k=10))

print(evaluate_metric(data, "sit_xl_w_o_cfg_prec", "iprec", k=10))
print(evaluate_metric(data, "sit_xl_w_cfg_prec", "iprec", k=10))

# %%
print(evaluate_metric(data, "sit_b_w_o_cfg_rec", "irec", k=10))
print(evaluate_metric(data, "sit_b_w_cfg_rec", "irec", k=10))

print(evaluate_metric(data, "sit_xl_w_o_cfg_rec", "irec", k=10))
print(evaluate_metric(data, "sit_xl_w_cfg_rec", "irec", k=10))

# %%
from ifid_data import plot_metric
plot_metric("reconstruction_rfid", "rFID", "sit_b_w_o_cfg_gfid", "SiT/B w/o CFG gFID")
plot_metric("reconstruction_rfid", "rFID", "sit_xl_w_o_cfg_gfid", "SiT/XL w/o CFG gFID")
plot_metric("ifid_bn", "iFID", "sit_b_w_o_cfg_gfid", "SiT/B w/o CFG gFID")
plot_metric("ifid_bn", "iFID", "sit_xl_w_o_cfg_gfid", "SiT/XL w/o CFG gFID")
# Out:
# Linear regression: y = -5.534 x + 31.815
# Pearson correlation: -0.127
# Linear regression: y = -2.063 x + 15.495
# Pearson correlation: -0.081
# Linear regression: y = 0.744 x + 4.890
# Pearson correlation: 0.859
# Linear regression: y = 0.427 x + 1.175
# Pearson correlation: 0.883
